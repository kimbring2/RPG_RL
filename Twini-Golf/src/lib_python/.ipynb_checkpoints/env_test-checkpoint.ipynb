# %%
import vizgolf as vzg
import time
import cv2
import numpy as np
import random

game = vzg.GolfGame()

game.add_available_button(vzg.Button.MOVE_FORWARD_BACKWARD_DELTA)
game.add_available_button(vzg.Button.MOVE_LEFT_RIGHT_DELTA)
game.add_available_button(vzg.Button.TURN_LEFT_RIGHT_DELTA)
game.add_available_button(vzg.Button.LOOK_UP_DOWN_DELTA)
#game.button_update()

game.init()
# Out:
# GolfGamePython::GolfGamePython()
# GolfGamePython::init()
# GolfGame::init()
# GolfController::init()
# (this->instanceId).c_str(): vpXFml5O6l
# server this->name.c_str(): ViZGolfMQGolfvpXFml5O6l
# server this->name.c_str(): ViZGolfMQCtrvpXFml5O6l
# GolfController::launchGolf()
# GolfController::handleSignals()
# TTF_init has failed. Error:
# Failed to load texture. Error: Couldn't open res/gfx/splashbg.png

# %%
game.send_command("3")

# %%
x_action_float = 0.0
y_action_float = -0.5

x_action_string = "{:+1.4f}".format(x_action_float)

y_action_string = "{:+1.4f}".format(y_action_float)
action_string = "1$" + x_action_string + "$" + y_action_string + "$"

game.send_command(action_string)
game.update_state()
state = game.get_state()
print("state.reward: ", state.reward)
# Out:
# state:  <vizgolf.GameState object at 0x7f9f2aed04f0>

# %%
game.update_state()
state = game.get_state()

for i in range(0, 500000):
    x_action_float = random.uniform(-0.5, 0.5)
    y_action_float = random.uniform(-0.5, 0.5)

    x_action_string = "{:+1.4f}".format(x_action_float)
    #print("x_action_string: ", x_action_string)

    y_action_string = "{:+1.4f}".format(y_action_float)
    #print("y_action_string: ", y_action_string)
    action_string = "1$" + x_action_string + "$" + y_action_string + "$"

    #print("state.labels[0].object_name: ", state.labels[0].object_name)
    #print("state.screen_buffer.shape: ", state.screen_buffer.shape)
    #screen_buffer = np.transpose(screen_buffer, (1, 2, 0))
    #print("screen_buffer.shape: ", screen_buffer.shape)
    cv2.imshow("screen_buffer", state.screen_buffer)
    cv2.waitKey(1)

    #game.send_command(action_string)
    #time.sleep(0.5)
    game.send_command(action_string)
    
    game.update_state()
    state = game.get_state()
# Out:
# server this->name.c_str(): ViZGolfMQCtr733SPg1wdB
# this->name.c_str(): ViZGolfSM733SPg1wdB
# this->golfController->disableAllButtons()
# this->availableButtons.size(): 4
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQGolf->send(MSG_CODE_COMMAND, command.c_str())
# received_msg.code: 24
# received_msg.command: action_end
# reward: 0.000000
# this->MQset ok
# msg.code: 24
# msg.command: 1$+0.1004$+0.1553$
# msg.code: 24
# msg.command: 1$-0.3457$-0.4661$
# msg.code: 24
# msg.command: 1$-0.1116$-0.1879$
# msg.code: 24
# msg.command: 1$-0.0554$+0.2479$
# msg.code: 24
# msg.command: 1$-0.1412$+0.0161$
# msg.code: 24
# msg.command: 1$-0.4196$-0.3814$
# msg.code: 24
# msg.command: 1$+0.3295$+0.3370$
# msg.code: 24
# msg.command: 1$-0.4542$-0.3583$
# msg.code: 24
# msg.command: 1$-0.2159$-0.1001$
# msg.code: 24
# msg.command: 1$+0.2249$+0.2360$
# msg.code: 24
# msg.command: 1$-0.1853$-0.0865$
# msg.code: 24
# msg.command: 1$-0.1246$-0.0731$
# msg.code: 24
# msg.command: 1$+0.3185$-0.4886$
# msg.code: 24
# msg.command: 1$-0.1826$+0.4029$
# msg.code: 24
# msg.command: 1$+0.2859$+0.4471$
# msg.code: 24
# msg.command: 1$+0.0239$-0.2176$
# msg.code: 24
# msg.command: 1$-0.0028$+0.2051$
# msg.code: 24
# msg.command: 1$-0.1174$-0.0113$
# msg.code: 24
# msg.command: 1$-0.1362$-0.4611$
# msg.code: 24
# msg.command: 1$-0.3672$+0.1982$
# msg.code: 24
# msg.command: 1$-0.1646$-0.3575$
# msg.code: 24
# msg.command: 1$+0.0185$+0.3146$
# msg.code: 24
# msg.command: 1$-0.4564$+0.3523$
# msg.code: 24
# msg.command: 1$+0.0069$-0.0853$
# msg.code: 24
# msg.command: 1$-0.2755$+0.0660$
# msg.code: 24
# msg.command: 1$+0.0717$-0.4119$
# msg.code: 24
# msg.command: 1$-0.1757$+0.2411$
# msg.code: 24
# msg.command: 1$-0.0186$-0.1941$
# msg.code: 24
# msg.command: 1$-0.0036$-0.4931$
# msg.code: 24
# msg.command: 1$+0.1842$+0.4428$
# msg.code: 24
# msg.command: 1$+0.4179$-0.3837$
# msg.code: 24
# msg.command: 1$-0.3021$-0.0575$
# msg.code: 24
# msg.command: 1$+0.0328$-0.1722$
# msg.code: 24
# msg.command: 1$-0.0566$-0.0741$
# msg.code: 24
# msg.command: 1$+0.4106$+0.2741$
# msg.code: 24
# msg.command: 1$+0.4089$+0.0769$
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <module>
#      20 cv2.waitKey(1)
#      22 #game.send_command(action_string)
#      23 #time.sleep(0.5)
# ---> 24 game.send_command(action_string)
#      26 game.update_state()
#      27 state = game.get_state()
#
# KeyboardInterrupt:
